# %% [markdown]
# Project 2 /
# Part 1: EDA

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/American Preparation/DAC K33/Python_Project 2/'
# Out:
# Mounted at /content/drive

# %%
df_payment = pd.read_csv(path + 'payment_report.csv')
df_product = pd.read_csv(path + 'product.csv')
df_transactions = pd.read_csv(path + 'transactions.csv')

# %%
#Merge file payment + product với điều kiện product_id
df_payment_enriched = pd.merge(df_payment,df_product, on='product_id')
df_payment_enriched.head()
# Out:
#   report_month payment_group  product_id  source_id     volume  category  \
# 0      2023-01       payment          12         45  624110375   PXXXXXT
# 1      2023-01       payment          17         45  335715113   PXXXXXB
# 2      2023-01       payment          18         45  737784466   PXXXXXB
# 3      2023-01       payment          19         45  120963069  PXXXXXM2
# 4      2023-01       payment          20         45  319653158   PXXXXXB
#
#   team_own
# 0      ASD
# 1      ASD
# 2      ASD
# 3      ASD
# 4      ASD

# %%
df_payment_enriched.info()
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   report_month   897 non-null    object
#  1   payment_group  897 non-null    object
#  2   product_id     897 non-null    int64
#  3   source_id      897 non-null    int64
#  4   volume         897 non-null    int64
#  5   category       897 non-null    object
#  6   team_own       897 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 49.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324002 entries, 0 to 1324001
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   transaction_id  1324002 non-null  int64
#  1   merchant_id     1324002 non-null  int64
#  2   volume          1324002 non-null  int64
#  3   transType       1324002 non-null  int64
#  4   transStatus     1324002 non-null  int64
#  5   sender_id       1274943 non-null  float64
#  6   receiver_id     1159207 non-null  float64
#  7   extra_info      6095 non-null     object
#  8   timeStamp       1324002 non-null  int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 90.9+ MB

# %%
df_transactions.head()
# Out:
#    transaction_id  merchant_id   volume  transType  transStatus   sender_id  \
# 0      3002692434            5   100000         24            1  10199794.0
# 1      3002692437          305    20000          2            1  14022211.0
# 2      3001960110         7255    48605         22            1         NaN
# 3      3002680710         2270  1500000          2            1  10059206.0
# 4      3002680713         2275    90000          2            1  10004711.0
#
#    receiver_id extra_info      timeStamp
# 0     199794.0        NaN  1682932054455
# 1   14022211.0        NaN  1682932054912
# 2   10530940.0        NaN  1682932055000
# 3      59206.0        NaN  1682932055622
# 4       4711.0        NaN  1682932056197

# %% [markdown]
# Missing data
# - Table df_transactions:
# - sender_id: 49059 missing rows, missing rate 3.7% --- Action: Ignore
# - receiver_id:  164795 missing rows, missing rate 12.4% --- Action: Ignore
# - extra_info: 1317907 missing rows, missing rate 99.5% --- Action: Ignore
#
# Incorrect Data Type
# - Table df_transactions:
# - sender_ id, receiver_id: float64 --- Action: convert to int64
# - time Stamp: int64 --- Action: convert to datetime
#
# - Table df_payment_enriched:
# - report_month: object --- Action: convert to datetime

# %%
if 'date' in df_transactions.columns:
    df_transactions = df_transactions.drop(columns=['date'])

# %%
# @title Default title text
#Table transactions
# Convert 'timeStamp' to datetime objects and update the existing column
df_transactions['timeStamp'] = pd.to_datetime(df_transactions['timeStamp'], unit='ms', errors='coerce').dt.to_pydatetime()
# Convert 'sender_id', 'receiver_id' to int64
df_transactions['sender_id'] = df_transactions['sender_id'].astype('Int64')
df_transactions['receiver_id'] = df_transactions['receiver_id'].astype('Int64')

#Table payment_enriched
# Convert 'report_month' to datetime
df_payment_enriched['report_month'] = pd.to_datetime(df_payment_enriched['report_month'])

# Display
df_transactions.head()
df_payment_enriched.head()
# Out:
# /tmp/ipython-input-4089751954.py:4: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_transactions['timeStamp'] = pd.to_datetime(df_transactions['timeStamp'], unit='ms', errors='coerce').dt.to_pydatetime()
#   report_month payment_group  product_id  source_id     volume  category  \
# 0   2023-01-01       payment          12         45  624110375   PXXXXXT
# 1   2023-01-01       payment          17         45  335715113   PXXXXXB
# 2   2023-01-01       payment          18         45  737784466   PXXXXXB
# 3   2023-01-01       payment          19         45  120963069  PXXXXXM2
# 4   2023-01-01       payment          20         45  319653158   PXXXXXB
#
#   team_own
# 0      ASD
# 1      ASD
# 2      ASD
# 3      ASD
# 4      ASD

# %%
df_transactions.info()
df_payment_enriched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324002 entries, 0 to 1324001
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   transaction_id  1324002 non-null  int64
#  1   merchant_id     1324002 non-null  int64
#  2   volume          1324002 non-null  int64
#  3   transType       1324002 non-null  int64
#  4   transStatus     1324002 non-null  int64
#  5   sender_id       1274943 non-null  Int64
#  6   receiver_id     1159207 non-null  Int64
#  7   extra_info      6095 non-null     object
#  8   timeStamp       1324002 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](1), int64(5), object(1)
# memory usage: 93.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   report_month   897 non-null    datetime64[ns]
#  1   payment_group  897 non-null    object
#  2   product_id     897 non-null    int64
#  3   source_id      897 non-null    int64
#  4   volume         897 non-null    int64
#  5   category       897 non-null    object
#  6   team_own       897 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 49.2+ KB

# %%
#check duplicate (have 25 duplicated rows --- Action: Delete)
df_transactions = df_transactions[~df_transactions.duplicated()] # Only keep rows which are not duplicates
df_transactions.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_payment_enriched.describe()
# Out:
#                      report_month    product_id  source_id        volume
# count                         897    897.000000      897.0  8.970000e+02
# mean   2023-02-19 07:45:33.110368   1139.573021       45.0  1.338153e+08
# min           2023-01-01 00:00:00     12.000000       45.0  1.000000e+04
# 25%           2023-02-01 00:00:00    634.000000       45.0  1.258000e+06
# 50%           2023-03-01 00:00:00   1023.000000       45.0  7.469786e+06
# 75%           2023-04-01 00:00:00   1578.000000       45.0  4.770741e+07
# max           2023-04-01 00:00:00  15067.000000       45.0  4.926051e+09
# std                           NaN   1161.547355        0.0  4.614672e+08

# %%
df_transactions.describe()
# Out:
#        transaction_id   merchant_id        volume     transType   transStatus  \
# count    1.323974e+06  1.323974e+06  1.323974e+06  1.323974e+06  1.323974e+06
# mean     3.002234e+09  2.460332e+03  2.388093e+05  6.979182e+00 -1.204636e+01
# min      3.000000e+09  5.000000e+00  1.000000e+00  2.000000e+00 -1.333000e+03
# 25%      3.001121e+09  3.050000e+02  1.000000e+04  2.000000e+00  1.000000e+00
# 50%      3.002200e+09  2.250000e+03  3.000000e+04  2.000000e+00  1.000000e+00
# 75%      3.003255e+09  2.270000e+03  1.000000e+05  8.000000e+00  1.000000e+00
# max      6.000066e+09  1.625250e+05  7.869148e+07  3.000000e+01  1.000000e+00
# std      1.042617e+07  3.304293e+03  9.681107e+05  7.459665e+00  5.577851e+01
#
#               sender_id       receiver_id                      timeStamp
# count         1274916.0         1159182.0                        1323974
# mean   103392211.603019  208488236.021155  2023-05-03 16:13:08.211815680
# min          10000007.0             -63.0     2023-04-30 17:00:00.095000
# 25%          10056567.0          152670.0  2023-05-02 02:13:58.307000064
# 50%          10942004.0         7025130.0  2023-05-03 06:50:19.884499968
# 75%          21012663.0        31512376.0  2023-05-05 06:49:20.503000064
# max        6993438823.0     21000000000.0     2023-05-07 16:59:59.495000
# std    623425527.063003  928782507.772746                            NaN

# %% [markdown]
# Nhận xét:
# - Min receiver_id: -63 --- Action: Delete

# %%
df_transactions = df_transactions[df_transactions['receiver_id'] != -63]
df_transactions.describe()
# Out:
#        transaction_id   merchant_id        volume     transType   transStatus  \
# count    1.159179e+06  1.159179e+06  1.159179e+06  1.159179e+06  1.159179e+06
# mean     3.002220e+09  2.062676e+03  2.042781e+05  7.624560e+00 -1.222898e+01
# min      3.000000e+09  5.000000e+00  1.000000e+00  2.000000e+00 -1.333000e+03
# 25%      3.001082e+09  3.050000e+02  5.000000e+03  2.000000e+00  1.000000e+00
# 50%      3.002177e+09  2.250000e+03  2.000000e+04  2.000000e+00  1.000000e+00
# 75%      3.003247e+09  2.270000e+03  1.000000e+05  8.000000e+00  1.000000e+00
# max      6.000066e+09  1.599300e+05  7.869148e+07  3.000000e+01  1.000000e+00
# std      1.109499e+07  1.887977e+03  8.735972e+05  7.647817e+00  5.582732e+01
#
#               sender_id       receiver_id                      timeStamp
# count         1112708.0         1159179.0                        1159179
# mean    98802633.142533  208488775.596922  2023-05-03 16:08:14.122548480
# min          10000007.0               0.0     2023-04-30 17:00:00.095000
# 25%          10056140.0          152684.0  2023-05-02 02:04:50.856999936
# 50%          11598191.0         7025130.0  2023-05-03 06:46:03.875000064
# 75%          21032263.0        31512386.5  2023-05-05 06:45:16.670000128
# max        6993438823.0     21000000000.0     2023-05-07 16:59:59.495000
# std    605421603.261831  928783649.074775                            NaN

# %% [markdown]
# # Data Wrangling

# %%
#1 Top 3 product_ids with the highest volume(cách 1)
product_with_volume = df_payment_enriched.groupby("product_id")["volume"].sum()
product_with_volume.sort_values(ascending=False).head(3)
# Out:
# product_id
# 429    14667676567
# 372    13713658515
# 431     7821984747
# Name: volume, dtype: int64

# %%
#1 Top 3 product_ids with the highest volume (cách 2)
group_product = df_payment_enriched.groupby('product_id')
#Tính tổng volume theo product
group_product.agg({'volume':'sum'})
#Tìm top 3 (Sort)
group_product.agg({'volume':'sum'}).sort_values(by='volume',ascending=False).head(3)
# Out:
#                  volume
# product_id
# 429         14667676567
# 372         13713658515
# 431          7821984747

# %%
#2 Given that 1 product_id is only owed by 1 team, are there any abnormal products against this rule?
product_with_team =df_product.groupby('product_id')['team_own'].nunique()
product_with_team.sort_values(ascending=False).head()
# Nhận xét: tất cả product đều thuộc 1 team
# Out:
# product_id
# 15067    1
# 9        1
# 10       1
# 11       1
# 12       1
# Name: team_own, dtype: int64

# %%
#3 Find the team has had the lowest performance (lowest volume) since Q2.2023. Find the category that contributes the least to that team.
#Filter data for records since quarter 2, 2023
filter_data = df_payment_enriched[df_payment_enriched['report_month'] >= pd.Timestamp('2023-04-01')]
team_with_volume = df_payment_enriched.groupby('team_own')['volume'].sum()
team_with_volume.sort_values(ascending=True).head(1)
# Out:
# team_own
# APS    272891202
# Name: volume, dtype: int64

# %%
print(df_payment['payment_group'].unique())
# Out:
# ['payment' 'refund']

# %%
#4 Find the contribution of source_ids of refund transactions (payment_group = ‘refund’), what is the source_id with the highest contribution?
#Filter payment_group = 'refund'
filter_payment_group = df_payment[df_payment['payment_group'] == 'refund']
source_with_volume = filter_payment_group.groupby('source_id')['volume'].sum()
source_with_volume.sort_values(ascending=False).head(1)
# Out:
# source_id
# 38    36527454759
# Name: volume, dtype: int64

# %%
#5 Define type of transactions (‘transaction_type’) for each row
def trans_type(trans):
  if trans.transType == 2 and trans.merchant_id == 1205:
    return "Bank Transfer Transaction"
  if trans.transType == 2 and trans.merchant_id == 2260:
    return "Withdraw Money Transaction"
  if trans.transType == 2 and trans.merchant_id == 2270:
    return "Top Up Money Transaction"
  if trans.transType == 2 and trans.merchant_id != 1205 and trans.merchant_id != 2260 and trans.merchant_id != 2270:
    return "Payment Transaction"
  if trans.transType == 8 and trans.merchant_id == 2250:
    return "Transfer Money Transaction"
  if trans.transType == 8 and trans.merchant_id !=2250:
    return "Slit Bill Transaction"
  else:
    return "Invalid Transaction"

# %%
df_transactions['trans_type'] = df_transactions.apply(trans_type, axis=1)
df_transactions.head()
# Out:
#    transaction_id  merchant_id   volume  transType  transStatus  sender_id  \
# 0      3002692434            5   100000         24            1   10199794
# 1      3002692437          305    20000          2            1   14022211
# 2      3001960110         7255    48605         22            1       <NA>
# 3      3002680710         2270  1500000          2            1   10059206
# 4      3002680713         2275    90000          2            1   10004711
#
#    receiver_id extra_info               timeStamp                trans_type
# 0       199794        NaN 2023-05-01 09:07:34.455       Invalid Transaction
# 1     14022211        NaN 2023-05-01 09:07:34.912       Payment Transaction
# 2     10530940        NaN 2023-05-01 09:07:35.000       Invalid Transaction
# 3        59206        NaN 2023-05-01 09:07:35.622  Top Up Money Transaction
# 4         4711        NaN 2023-05-01 09:07:36.197       Payment Transaction

# %%
#6 Of each transaction type (excluding invalid transactions): find the number of transactions, volume, senders and receivers.
#filter transaction type exclude invalid transactions
df_transactions = df_transactions[df_transactions['trans_type'] != 'Invalid Transaction']
df_transactions.groupby('trans_type').agg({'transaction_id':'count','volume':'sum','sender_id':'count','receiver_id':'count'})
# Out:
#                             transaction_id        volume  sender_id  \
# trans_type
# Bank Transfer Transaction            14004   10061351762      14004
# Payment Transaction                 260332   34385216147     260332
# Slit Bill Transaction                 1376       4901464       1376
# Top Up Money Transaction            290498  108605618829     290498
# Transfer Money Transaction          341173   37032880492     341173
# Withdraw Money Transaction           33725   23418181420      33725
#
#                             receiver_id
# trans_type
# Bank Transfer Transaction         14004
# Payment Transaction              260332
# Slit Bill Transaction              1376
# Top Up Money Transaction         290498
# Transfer Money Transaction       341173
# Withdraw Money Transaction        33725
